# %%
import os
import json
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
import http.client

conn = http.client.HTTPSConnection("api.collectapi.com")

headers = {
    'content-type': "application/json",
    'authorization': f"apikey {os.getenv('COLLECT_API_KEY')}"
    }

conn.request("GET", "/gasPrice/allUsaPrice", headers=headers)

res = conn.getresponse()
data = res.read()

data_json = data.decode('utf-8')

json.loads(data)
# Out:
# {'success': True,
#  'result': [{'currency': 'usd',
#    'name': 'Alaska',
#    'regular': '$3.761',
#    'midGrade': '$3.975',
#    'premium': '$4.220',
#    'diesel': '$4.047'},
#   {'currency': 'usd',
#    'name': 'Alabama',
#    'regular': '$2.766',
#    'midGrade': '$3.200',
#    'premium': '$3.593',
#    'diesel': '$3.438'},
#   {'currency': 'usd',
#    'name': 'Arkansas',
#    'regular': '$2.737',
#    'midGrade': '$3.151',
#    'premium': '$3.540',
#    'diesel': '$3.357'},
#   {'currency': 'usd',
#    'name': 'Arizona',
#    'regular': '$3.231',
#    'midGrade': '$3.583',
#    'premium': '$3.904',
#    'diesel': '$3.608'},
#   {'currency': 'usd',
#    'name': 'California',
#    'regular': '$4.497',
#    'midGrade': '$4.718',
#    'premium': '$4.908',
#    'diesel': '$5.109'},
#   {'currency': 'usd',
#    'name': 'Colorado',
#    'regular': '$3.046',
#    'midGrade': '$3.424',
#    'premium': '$3.760',
#    'diesel': '$3.488'},
#   {'currency': 'usd',
#    'name': 'Connecticut',
#    'regular': '$3.104',
#    'midGrade': '$3.717',
#    'premium': '$4.084',
#    'diesel': '$3.770'},
#   {'currency': 'usd',
#    'name': 'District of Columbia',
#    'regular': '$3.288',
#    'midGrade': '$3.861',
#    'premium': '$4.288',
#    'diesel': '$3.812'},
#   {'currency': 'usd',
#    'name': 'Delaware',
#    'regular': '$3.037',
#    'midGrade': '$3.613',
#    'premium': '$3.893',
#    'diesel': '$3.810'},
#   {'currency': 'usd',
#    'name': 'Florida',
#    'regular': '$3.066',
#    'midGrade': '$3.510',
#    'premium': '$3.825',
#    'diesel': '$3.635'},
#   {'currency': 'usd',
#    'name': 'Georgia',
#    'regular': '$2.907',
#    'midGrade': '$3.347',
#    'premium': '$3.750',
#    'diesel': '$3.547'},
#   {'currency': 'usd',
#    'name': 'Hawaii',
#    'regular': '$4.457',
#    'midGrade': '$4.694',
#    'premium': '$4.943',
#    'diesel': '$5.223'},
#   {'currency': 'usd',
#    'name': 'Iowa',
#    'regular': '$2.897',
#    'midGrade': '$3.226',
#    'premium': '$3.699',
#    'diesel': '$3.527'},
#   {'currency': 'usd',
#    'name': 'Idaho',
#    'regular': '$3.516',
#    'midGrade': '$3.781',
#    'premium': '$4.052',
#    'diesel': '$3.932'},
#   {'currency': 'usd',
#    'name': 'Illinois',
#    'regular': '$3.403',
#    'midGrade': '$3.990',
#    'premium': '$4.453',
#    'diesel': '$3.753'},
#   {'currency': 'usd',
#    'name': 'Indiana',
#    'regular': '$3.195',
#    'midGrade': '$3.735',
#    'premium': '$4.226',
#    'diesel': '$3.818'},
#   {'currency': 'usd',
#    'name': 'Kansas',
#    'regular': '$2.835',
#    'midGrade': '$3.161',
#    'premium': '$3.503',
#    'diesel': '$3.445'},
#   {'currency': 'usd',
#    'name': 'Kentucky',
#    'regular': '$2.844',
#    'midGrade': '$3.390',
#    'premium': '$3.809',
#    'diesel': '$3.388'},
#   {'currency': 'usd',
#    'name': 'Louisiana',
#    'regular': '$2.740',
#    'midGrade': '$3.172',
#    'premium': '$3.547',
#    'diesel': '$3.297'},
#   {'currency': 'usd',
#    'name': 'Massachusetts',
#    'regular': '$3.058',
#    'midGrade': '$3.664',
#    'premium': '$4.037',
#    'diesel': '$3.846'},
#   {'currency': 'usd',
#    'name': 'Maryland',
#    'regular': '$3.108',
#    'midGrade': '$3.687',
#    'premium': '$3.985',
#    'diesel': '$3.839'},
#   {'currency': 'usd',
#    'name': 'Maine',
#    'regular': '$3.078',
#    'midGrade': '$3.623',
#    'premium': '$4.093',
#    'diesel': '$3.893'},
#   {'currency': 'usd',
#    'name': 'Michigan',
#    'regular': '$3.116',
#    'midGrade': '$3.666',
#    'premium': '$4.229',
#    'diesel': '$3.713'},
#   {'currency': 'usd',
#    'name': 'Minnesota',
#    'regular': '$2.942',
#    'midGrade': '$3.334',
#    'premium': '$3.777',
#    'diesel': '$3.592'},
#   {'currency': 'usd',
#    'name': 'Missouri',
#    'regular': '$2.826',
#    'midGrade': '$3.188',
#    'premium': '$3.507',
#    'diesel': '$3.430'},
#   {'currency': 'usd',
#    'name': 'Mississippi',
#    'regular': '$2.683',
#    'midGrade': '$3.112',
#    'premium': '$3.488',
#    'diesel': '$3.267'},
#   {'currency': 'usd',
#    'name': 'Montana',
#    'regular': '$3.241',
#    'midGrade': '$3.538',
#    'premium': '$3.894',
#    'diesel': '$3.644'},
#   {'currency': 'usd',
#    'name': 'North Carolina',
#    'regular': '$2.858',
#    'midGrade': '$3.303',
#    'premium': '$3.692',
#    'diesel': '$3.469'},
#   {'currency': 'usd',
#    'name': 'North Dakota',
#    'regular': '$2.898',
#    'midGrade': '$3.223',
#    'premium': '$3.603',
#    'diesel': '$3.428'},
#   {'currency': 'usd',
#    'name': 'Nebraska',
#    'regular': '$2.894',
#    'midGrade': '$3.135',
#    'premium': '$3.646',
#    'diesel': '$3.407'},
#   {'currency': 'usd',
#    'name': 'New Hampshire',
#    'regular': '$2.992',
#    'midGrade': '$3.568',
#    'premium': '$4.002',
#    'diesel': '$3.816'},
#   {'currency': 'usd',
#    'name': 'New Jersey',
#    'regular': '$3.030',
#    'midGrade': '$3.570',
#    'premium': '$3.828',
#    'diesel': '$3.672'},
#   {'currency': 'usd',
#    'name': 'New Mexico',
#    'regular': '$2.892',
#    'midGrade': '$3.284',
#    'premium': '$3.594',
#    'diesel': '$3.479'},
#   {'currency': 'usd',
#    'name': 'Nevada',
#    'regular': '$3.732',
#    'midGrade': '$4.017',
#    'premium': '$4.295',
#    'diesel': '$3.904'},
#   {'currency': 'usd',
#    'name': 'New York',
#    'regular': '$3.158',
#    'midGrade': '$3.668',
#    'premium': '$4.056',
#    'diesel': '$3.904'},
#   {'currency': 'usd',
#    'name': 'Ohio',
#    'regular': '$3.052',
#    'midGrade': '$3.588',
#    'premium': '$4.099',
#    'diesel': '$3.678'},
#   {'currency': 'usd',
#    'name': 'Oklahoma',
#    'regular': '$2.674',
#    'midGrade': '$3.046',
#    'premium': '$3.345',
#    'diesel': '$3.231'},
#   {'currency': 'usd',
#    'name': 'Oregon',
#    'regular': '$3.984',
#    'midGrade': '$4.209',
#    'premium': '$4.477',
#    'diesel': '$4.467'},
#   {'currency': 'usd',
#    'name': 'Pennsylvania',
#    'regular': '$3.219',
#    'midGrade': '$3.665',
#    'premium': '$4.026',
#    'diesel': '$4.005'},
#   {'currency': 'usd',
#    'name': 'Rhode Island',
#    'regular': '$3.032',
#    'midGrade': '$3.775',
#    'premium': '$4.146',
#    'diesel': '$3.810'},
#   {'currency': 'usd',
#    'name': 'South Carolina',
#    'regular': '$2.768',
#    'midGrade': '$3.212',
#    'premium': '$3.584',
#    'diesel': '$3.418'},
#   {'currency': 'usd',
#    'name': 'South Dakota',
#    'regular': '$2.937',
#    'midGrade': '$3.124',
#    'premium': '$3.615',
#    'diesel': '$3.383'},
#   {'currency': 'usd',
#    'name': 'Tennessee',
#    'regular': '$2.747',
#    'midGrade': '$3.197',
#    'premium': '$3.597',
#    'diesel': '$3.397'},
#   {'currency': 'usd',
#    'name': 'Texas',
#    'regular': '$2.754',
#    'midGrade': '$3.216',
#    'premium': '$3.572',
#    'diesel': '$3.157'},
#   {'currency': 'usd',
#    'name': 'Utah',
#    'regular': '$3.338',
#    'midGrade': '$3.610',
#    'premium': '$3.842',
#    'diesel': '$3.719'},
#   {'currency': 'usd',
#    'name': 'Virginia',
#    'regular': '$2.979',
#    'midGrade': '$3.441',
#    'premium': '$3.825',
#    'diesel': '$3.654'},
#   {'currency': 'usd',
#    'name': 'Vermont',
#    'regular': '$3.091',
#    'midGrade': '$3.651',
#    'premium': '$4.063',
#    'diesel': '$3.818'},
#   {'currency': 'usd',
#    'name': 'Washington',
#    'regular': '$4.408',
#    'midGrade': '$4.630',
#    'premium': '$4.890',
#    'diesel': '$5.019'},
#   {'currency': 'usd',
#    'name': 'Wisconsin',
#    'regular': '$2.838',
#    'midGrade': '$3.360',
#    'premium': '$3.850',
#    'diesel': '$3.503'},
#   {'currency': 'usd',
#    'name': 'West Virginia',
#    'regular': '$3.014',
#    'midGrade': '$3.435',
#    'premium': '$3.872',
#    'diesel': '$3.598'},
#   {'currency': 'usd',
#    'name': 'Wyoming',
#    'regular': '$3.085',
#    'midGrade': '$3.365',
#    'premium': '$3.657',
#    'diesel': '$3.607'}]}

# %%
print(data_json)
# Out:
# {"success":true,"result":[{"currency":"usd","name":"Alaska","regular":"$3.761","midGrade":"$3.975","premium":"$4.220","diesel":"$4.047"},{"currency":"usd","name":"Alabama","regular":"$2.766","midGrade":"$3.200","premium":"$3.593","diesel":"$3.438"},{"currency":"usd","name":"Arkansas","regular":"$2.737","midGrade":"$3.151","premium":"$3.540","diesel":"$3.357"},{"currency":"usd","name":"Arizona","regular":"$3.231","midGrade":"$3.583","premium":"$3.904","diesel":"$3.608"},{"currency":"usd","name":"California","regular":"$4.497","midGrade":"$4.718","premium":"$4.908","diesel":"$5.109"},{"currency":"usd","name":"Colorado","regular":"$3.046","midGrade":"$3.424","premium":"$3.760","diesel":"$3.488"},{"currency":"usd","name":"Connecticut","regular":"$3.104","midGrade":"$3.717","premium":"$4.084","diesel":"$3.770"},{"currency":"usd","name":"District of Columbia","regular":"$3.288","midGrade":"$3.861","premium":"$4.288","diesel":"$3.812"},{"currency":"usd","name":"Delaware","regular":"$3.037","midGrade":"$3.613","premium":"$3.893","diesel":"$3.810"},{"currency":"usd","name":"Florida","regular":"$3.066","midGrade":"$3.510","premium":"$3.825","diesel":"$3.635"},{"currency":"usd","name":"Georgia","regular":"$2.907","midGrade":"$3.347","premium":"$3.750","diesel":"$3.547"},{"currency":"usd","name":"Hawaii","regular":"$4.457","midGrade":"$4.694","premium":"$4.943","diesel":"$5.223"},{"currency":"usd","name":"Iowa","regular":"$2.897","midGrade":"$3.226","premium":"$3.699","diesel":"$3.527"},{"currency":"usd","name":"Idaho","regular":"$3.516","midGrade":"$3.781","premium":"$4.052","diesel":"$3.932"},{"currency":"usd","name":"Illinois","regular":"$3.403","midGrade":"$3.990","premium":"$4.453","diesel":"$3.753"},{"currency":"usd","name":"Indiana","regular":"$3.195","midGrade":"$3.735","premium":"$4.226","diesel":"$3.818"},{"currency":"usd","name":"Kansas","regular":"$2.835","midGrade":"$3.161","premium":"$3.503","diesel":"$3.445"},{"currency":"usd","name":"Kentucky","regular":"$2.844","midGrade":"$3.390","premium":"$3.809","diesel":"$3.388"},{"currency":"usd","name":"Louisiana","regular":"$2.740","midGrade":"$3.172","premium":"$3.547","diesel":"$3.297"},{"currency":"usd","name":"Massachusetts","regular":"$3.058","midGrade":"$3.664","premium":"$4.037","diesel":"$3.846"},{"currency":"usd","name":"Maryland","regular":"$3.108","midGrade":"$3.687","premium":"$3.985","diesel":"$3.839"},{"currency":"usd","name":"Maine","regular":"$3.078","midGrade":"$3.623","premium":"$4.093","diesel":"$3.893"},{"currency":"usd","name":"Michigan","regular":"$3.116","midGrade":"$3.666","premium":"$4.229","diesel":"$3.713"},{"currency":"usd","name":"Minnesota","regular":"$2.942","midGrade":"$3.334","premium":"$3.777","diesel":"$3.592"},{"currency":"usd","name":"Missouri","regular":"$2.826","midGrade":"$3.188","premium":"$3.507","diesel":"$3.430"},{"currency":"usd","name":"Mississippi","regular":"$2.683","midGrade":"$3.112","premium":"$3.488","diesel":"$3.267"},{"currency":"usd","name":"Montana","regular":"$3.241","midGrade":"$3.538","premium":"$3.894","diesel":"$3.644"},{"currency":"usd","name":"North Carolina","regular":"$2.858","midGrade":"$3.303","premium":"$3.692","diesel":"$3.469"},{"currency":"usd","name":"North Dakota","regular":"$2.898","midGrade":"$3.223","premium":"$3.603","diesel":"$3.428"},{"currency":"usd","name":"Nebraska","regular":"$2.894","midGrade":"$3.135","premium":"$3.646","diesel":"$3.407"},{"currency":"usd","name":"New Hampshire","regular":"$2.992","midGrade":"$3.568","premium":"$4.002","diesel":"$3.816"},{"currency":"usd","name":"New Jersey","regular":"$3.030","midGrade":"$3.570","premium":"$3.828","diesel":"$3.672"},{"currency":"usd","name":"New Mexico","regular":"$2.892","midGrade":"$3.284","premium":"$3.594","diesel":"$3.479"},{"currency":"usd","name":"Nevada","regular":"$3.732","midGrade":"$4.017","premium":"$4.295","diesel":"$3.904"},{"currency":"usd","name":"New York","regular":"$3.158","midGrade":"$3.668","premium":"$4.056","diesel":"$3.904 ...

# %%
gas_data = json.loads(data)["result"]
gas_data
# Out:
# [{'currency': 'usd',
#   'name': 'Alaska',
#   'regular': '$3.761',
#   'midGrade': '$3.975',
#   'premium': '$4.220',
#   'diesel': '$4.047'},
#  {'currency': 'usd',
#   'name': 'Alabama',
#   'regular': '$2.766',
#   'midGrade': '$3.200',
#   'premium': '$3.593',
#   'diesel': '$3.438'},
#  {'currency': 'usd',
#   'name': 'Arkansas',
#   'regular': '$2.737',
#   'midGrade': '$3.151',
#   'premium': '$3.540',
#   'diesel': '$3.357'},
#  {'currency': 'usd',
#   'name': 'Arizona',
#   'regular': '$3.231',
#   'midGrade': '$3.583',
#   'premium': '$3.904',
#   'diesel': '$3.608'},
#  {'currency': 'usd',
#   'name': 'California',
#   'regular': '$4.497',
#   'midGrade': '$4.718',
#   'premium': '$4.908',
#   'diesel': '$5.109'},
#  {'currency': 'usd',
#   'name': 'Colorado',
#   'regular': '$3.046',
#   'midGrade': '$3.424',
#   'premium': '$3.760',
#   'diesel': '$3.488'},
#  {'currency': 'usd',
#   'name': 'Connecticut',
#   'regular': '$3.104',
#   'midGrade': '$3.717',
#   'premium': '$4.084',
#   'diesel': '$3.770'},
#  {'currency': 'usd',
#   'name': 'District of Columbia',
#   'regular': '$3.288',
#   'midGrade': '$3.861',
#   'premium': '$4.288',
#   'diesel': '$3.812'},
#  {'currency': 'usd',
#   'name': 'Delaware',
#   'regular': '$3.037',
#   'midGrade': '$3.613',
#   'premium': '$3.893',
#   'diesel': '$3.810'},
#  {'currency': 'usd',
#   'name': 'Florida',
#   'regular': '$3.066',
#   'midGrade': '$3.510',
#   'premium': '$3.825',
#   'diesel': '$3.635'},
#  {'currency': 'usd',
#   'name': 'Georgia',
#   'regular': '$2.907',
#   'midGrade': '$3.347',
#   'premium': '$3.750',
#   'diesel': '$3.547'},
#  {'currency': 'usd',
#   'name': 'Hawaii',
#   'regular': '$4.457',
#   'midGrade': '$4.694',
#   'premium': '$4.943',
#   'diesel': '$5.223'},
#  {'currency': 'usd',
#   'name': 'Iowa',
#   'regular': '$2.897',
#   'midGrade': '$3.226',
#   'premium': '$3.699',
#   'diesel': '$3.527'},
#  {'currency': 'usd',
#   'name': 'Idaho',
#   'regular': '$3.516',
#   'midGrade': '$3.781',
#   'premium': '$4.052',
#   'diesel': '$3.932'},
#  {'currency': 'usd',
#   'name': 'Illinois',
#   'regular': '$3.403',
#   'midGrade': '$3.990',
#   'premium': '$4.453',
#   'diesel': '$3.753'},
#  {'currency': 'usd',
#   'name': 'Indiana',
#   'regular': '$3.195',
#   'midGrade': '$3.735',
#   'premium': '$4.226',
#   'diesel': '$3.818'},
#  {'currency': 'usd',
#   'name': 'Kansas',
#   'regular': '$2.835',
#   'midGrade': '$3.161',
#   'premium': '$3.503',
#   'diesel': '$3.445'},
#  {'currency': 'usd',
#   'name': 'Kentucky',
#   'regular': '$2.844',
#   'midGrade': '$3.390',
#   'premium': '$3.809',
#   'diesel': '$3.388'},
#  {'currency': 'usd',
#   'name': 'Louisiana',
#   'regular': '$2.740',
#   'midGrade': '$3.172',
#   'premium': '$3.547',
#   'diesel': '$3.297'},
#  {'currency': 'usd',
#   'name': 'Massachusetts',
#   'regular': '$3.058',
#   'midGrade': '$3.664',
#   'premium': '$4.037',
#   'diesel': '$3.846'},
#  {'currency': 'usd',
#   'name': 'Maryland',
#   'regular': '$3.108',
#   'midGrade': '$3.687',
#   'premium': '$3.985',
#   'diesel': '$3.839'},
#  {'currency': 'usd',
#   'name': 'Maine',
#   'regular': '$3.078',
#   'midGrade': '$3.623',
#   'premium': '$4.093',
#   'diesel': '$3.893'},
#  {'currency': 'usd',
#   'name': 'Michigan',
#   'regular': '$3.116',
#   'midGrade': '$3.666',
#   'premium': '$4.229',
#   'diesel': '$3.713'},
#  {'currency': 'usd',
#   'name': 'Minnesota',
#   'regular': '$2.942',
#   'midGrade': '$3.334',
#   'premium': '$3.777',
#   'diesel': '$3.592'},
#  {'currency': 'usd',
#   'name': 'Missouri',
#   'regular': '$2.826',
#   'midGrade': '$3.188',
#   'premium': '$3.507',
#   'diesel': '$3.430'},
#  {'currency': 'usd',
#   'name': 'Mississippi',
#   'regular': '$2.683',
#   'midGrade': '$3.112',
#   'premium': '$3.488',
#   'diesel': '$3.267'},
#  {'currency': 'usd',
#   'name': 'Montana',
#   'regular': '$3.241',
#   'midGrade': '$3.538',
#   'premium': '$3.894',
#   'diesel': '$3.644'},
#  {'currency': 'usd',
#   'name': 'North Carolina',
#   'regular': '$2.858',
#   'midGrade': '$3.303',
#   'premium': '$3.692',
#   'diesel': '$3.469'},
#  {'currency': 'usd',
#   'name': 'North Dakota',
#   'regular': '$2.898',
#   'midGrade': '$3.223',
#   'premium': '$3.603',
#   'diesel': '$3.428'},
#  {'currency': 'usd',
#   'name': 'Nebraska',
#   'regular': '$2.894',
#   'midGrade': '$3.135',
#   'premium': '$3.646',
#   'diesel': '$3.407'},
#  {'currency': 'usd',
#   'name': 'New Hampshire',
#   'regular': '$2.992',
#   'midGrade': '$3.568',
#   'premium': '$4.002',
#   'diesel': '$3.816'},
#  {'currency': 'usd',
#   'name': 'New Jersey',
#   'regular': '$3.030',
#   'midGrade': '$3.570',
#   'premium': '$3.828',
#   'diesel': '$3.672'},
#  {'currency': 'usd',
#   'name': 'New Mexico',
#   'regular': '$2.892',
#   'midGrade': '$3.284',
#   'premium': '$3.594',
#   'diesel': '$3.479'},
#  {'currency': 'usd',
#   'name': 'Nevada',
#   'regular': '$3.732',
#   'midGrade': '$4.017',
#   'premium': '$4.295',
#   'diesel': '$3.904'},
#  {'currency': 'usd',
#   'name': 'New York',
#   'regular': '$3.158',
#   'midGrade': '$3.668',
#   'premium': '$4.056',
#   'diesel': '$3.904'},
#  {'currency': 'usd',
#   'name': 'Ohio',
#   'regular': '$3.052',
#   'midGrade': '$3.588',
#   'premium': '$4.099',
#   'diesel': '$3.678'},
#  {'currency': 'usd',
#   'name': 'Oklahoma',
#   'regular': '$2.674',
#   'midGrade': '$3.046',
#   'premium': '$3.345',
#   'diesel': '$3.231'},
#  {'currency': 'usd',
#   'name': 'Oregon',
#   'regular': '$3.984',
#   'midGrade': '$4.209',
#   'premium': '$4.477',
#   'diesel': '$4.467'},
#  {'currency': 'usd',
#   'name': 'Pennsylvania',
#   'regular': '$3.219',
#   'midGrade': '$3.665',
#   'premium': '$4.026',
#   'diesel': '$4.005'},
#  {'currency': 'usd',
#   'name': 'Rhode Island',
#   'regular': '$3.032',
#   'midGrade': '$3.775',
#   'premium': '$4.146',
#   'diesel': '$3.810'},
#  {'currency': 'usd',
#   'name': 'South Carolina',
#   'regular': '$2.768',
#   'midGrade': '$3.212',
#   'premium': '$3.584',
#   'diesel': '$3.418'},
#  {'currency': 'usd',
#   'name': 'South Dakota',
#   'regular': '$2.937',
#   'midGrade': '$3.124',
#   'premium': '$3.615',
#   'diesel': '$3.383'},
#  {'currency': 'usd',
#   'name': 'Tennessee',
#   'regular': '$2.747',
#   'midGrade': '$3.197',
#   'premium': '$3.597',
#   'diesel': '$3.397'},
#  {'currency': 'usd',
#   'name': 'Texas',
#   'regular': '$2.754',
#   'midGrade': '$3.216',
#   'premium': '$3.572',
#   'diesel': '$3.157'},
#  {'currency': 'usd',
#   'name': 'Utah',
#   'regular': '$3.338',
#   'midGrade': '$3.610',
#   'premium': '$3.842',
#   'diesel': '$3.719'},
#  {'currency': 'usd',
#   'name': 'Virginia',
#   'regular': '$2.979',
#   'midGrade': '$3.441',
#   'premium': '$3.825',
#   'diesel': '$3.654'},
#  {'currency': 'usd',
#   'name': 'Vermont',
#   'regular': '$3.091',
#   'midGrade': '$3.651',
#   'premium': '$4.063',
#   'diesel': '$3.818'},
#  {'currency': 'usd',
#   'name': 'Washington',
#   'regular': '$4.408',
#   'midGrade': '$4.630',
#   'premium': '$4.890',
#   'diesel': '$5.019'},
#  {'currency': 'usd',
#   'name': 'Wisconsin',
#   'regular': '$2.838',
#   'midGrade': '$3.360',
#   'premium': '$3.850',
#   'diesel': '$3.503'},
#  {'currency': 'usd',
#   'name': 'West Virginia',
#   'regular': '$3.014',
#   'midGrade': '$3.435',
#   'premium': '$3.872',
#   'diesel': '$3.598'},
#  {'currency': 'usd',
#   'name': 'Wyoming',
#   'regular': '$3.085',
#   'midGrade': '$3.365',
#   'premium': '$3.657',
#   'diesel': '$3.607'}]

# %%
gas_df = pd.DataFrame(gas_data).to_js
gas_df.head()
# Out:
#   currency        name regular midGrade premium  diesel
# 0      usd      Alaska  $3.761   $3.975  $4.220  $4.047
# 1      usd     Alabama  $2.766   $3.200  $3.593  $3.438
# 2      usd    Arkansas  $2.737   $3.151  $3.540  $3.357
# 3      usd     Arizona  $3.231   $3.583  $3.904  $3.608
# 4      usd  California  $4.497   $4.718  $4.908  $5.109

# %%
gas_df = gas_df.rename(columns={"name":"city"})
gas_df.head()
# Out:
#   currency        city regular midGrade premium  diesel
# 0      usd      Alaska  $3.761   $3.975  $4.220  $4.047
# 1      usd     Alabama  $2.766   $3.200  $3.593  $3.438
# 2      usd    Arkansas  $2.737   $3.151  $3.540  $3.357
# 3      usd     Arizona  $3.231   $3.583  $3.904  $3.608
# 4      usd  California  $4.497   $4.718  $4.908  $5.109

# %%
# gas_df.drop(columns='lowername', inplace=True)

# %%
db_ur = os.getenv("DATA_BASE_URI2")
engine = create_engine(url=db_ur)
with engine.connect() as connection:
    gas_df.to_sql(name='gas_price_data', con=engine, if_exists='append', index=False)
    pass
# Out:
# postgresql+psycopg2://avnadmin:AVNS_OQ5_dSlMAfLfQcQEE-b@walter-walterbilionnaire-4951.j.aivencloud.com:11167/defaultdb?sslmode=require

# %%
# gas_df.to_sql(name='gas_price_data', con=engine, if_exists='append', index=False)
